# %% [markdown]
# # Markdown

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
sns.set()
bmi_data = pd.read_csv("data/BMI-USA.csv",encoding='iso-8859-1') 
diabetes_data = pd.read_csv("data/diabetes-USA.csv")
height_data = pd.read_csv("data/height-USA.csv")
BP_data = pd.read_csv("data/BP-USA.csv")
bmi_data.head()
# Out:
#        Country/Region/World  ISO  Sex  Year   Mean BMI  \
# 0  United States of America  USA  Men  1975  25.289004
# 1  United States of America  USA  Men  1976  25.347719
# 2  United States of America  USA  Men  1977  25.405960
# 3  United States of America  USA  Men  1978  25.465292
# 4  United States of America  USA  Men  1979  25.527234
#
#    Mean BMI lower 95% uncertainty interval  \
# 0                                24.754709
# 1                                24.870465
# 2                                24.967831
# 3                                25.051328
# 4                                25.122793
#
#    Mean BMI upper 95% uncertainty interval  \
# 0                                25.823230
# 1                                25.826762
# 2                                25.852935
# 3                                25.885462
# 4                                25.936497
#
#    Prevalence of BMI>=30 kg/m² (obesity)  \
# 0                               0.107136
# ...

# %%
sns.scatterplot(data=bmi_data,x="Year",y="Mean BMI",hue="Sex")

# %%
diabetes_data.head(50)
# Out:
#                      Country    Sex  Year  \
# 0   United States of America    Men  1980
# 1   United States of America    Men  1981
# 2   United States of America    Men  1982
# 3   United States of America    Men  1983
# 4   United States of America    Men  1984
# 5   United States of America    Men  1985
# 6   United States of America    Men  1986
# 7   United States of America    Men  1987
# 8   United States of America    Men  1988
# 9   United States of America    Men  1989
# 10  United States of America    Men  1990
# 11  United States of America    Men  1991
# 12  United States of America    Men  1992
# 13  United States of America    Men  1993
# 14  United States of America    Men  1994
# 15  United States of America    Men  1995
# 16  United States of America    Men  1996
# 17  United States of America    Men  1997
# 18  United States of America    Men  1998
# 19  United States of America    Men  1999
# 20  United States of America    Men  2000
# ...

# %%
sns.relplot(x="Year",y="Age-standardised diabetes prevalence", hue = "Sex", data=diabetes_data)

# %%
height_data.head()
# Out:
#                     Country  ... Mean height upper 95% uncertainty interval (cm)
# 0  United States of America  ...                                      172.260045
# 1  United States of America  ...                                      172.293362
# 2  United States of America  ...                                      172.325284
# 3  United States of America  ...                                      172.372466
# 4  United States of America  ...                                      172.430823
#
# [5 rows x 7 columns]

# %%
sns.relplot(x="Year of birth",y="Mean height (cm)", hue = "Sex", data=height_data)

# %%
BP_data.head(melt
# Out:
#                     Country  ... Number of adults with raised blood pressure upper 95% uncertainty interval
# 0  United States of America  ...                                       2.935587e+07
# 1  United States of America  ...                                       2.856802e+07
# 2  United States of America  ...                                       2.784962e+07
# 3  United States of America  ...                                       2.719215e+07
# 4  United States of America  ...                                       2.660490e+07
#
# [5 rows x 18 columns]

# %%
sns.relplot(data=BP_data,y = "Age-standardised mean systolic blood pressure (mmHg)",x = "Year",hue="Sex")
sns.relplot(data=BP_data,y = "Age-standardised mean diastolic blood pressure (mmHg)",x = "Year",hue="Sex")
